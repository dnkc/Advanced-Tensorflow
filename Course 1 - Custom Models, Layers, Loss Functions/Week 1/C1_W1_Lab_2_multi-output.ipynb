# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 928us/sample - loss: 280.0343 - y1_output_loss: 123.8848 - y2_output_loss: 153.5197 - y1_output_root_mean_squared_error: 11.1840 - y2_output_root_mean_squared_error: 12.4480 - val_loss: 50.8116 - val_y1_output_loss: 19.7775 - val_y2_output_loss: 29.2095 - val_y1_output_root_mean_squared_error: 4.5320 - val_y2_output_root_mean_squared_error: 5.5020
# Epoch 2/500
# 614/614 [==============================] - 0s 163us/sample - loss: 37.3489 - y1_output_loss: 13.8229 - y2_output_loss: 23.2502 - y1_output_root_mean_squared_error: 3.7271 - y2_output_root_mean_squared_error: 4.8433 - val_loss: 20.0213 - val_y1_output_loss: 9.3616 - val_y2_output_loss: 9.9401 - val_y1_output_root_mean_squared_error: 3.1185 - val_y2_output_root_mean_squared_error: 3.2088
# Epoch 3/500
# 614/614 [==============================] - 0s 149us/sample - loss: 28.0583 - y1_output_loss: 10.4257 - y2_output_loss: 17.4946 - y1_output_root_mean_squared_error: 3.2405 - y2_output_root_mean_squared_error: 4.1901 - val_loss: 20.4759 - val_y1_output_loss: 8.9797 - val_y2_output_loss: 10.7927 - val_y1_output_root_mean_squared_error: 3.0518 - val_y2_output_root_mean_squared_error: 3.3410
# Epoch 4/500
# 614/614 [==============================] - 0s 139us/sample - loss: 25.2214 - y1_output_loss: 10.1135 - y2_output_loss: 15.6408 - y1_output_root_mean_squared_error: 3.1458 - y2_output_root_mean_squared_error: 3.9147 - val_loss: 31.4310 - val_y1_output_loss: 12.6590 - val_y2_output_loss: 17.6914 - val_y1_output_root_mean_squared_error: 3.6218 - val_y2_output_root_mean_squared_error: 4.2795
# Epoch 5/500
# 614/614 [==============================] - 0s 136us/sample - loss: 29.7431 - y1_output_loss: 10.7024 - y2_output_loss: 18.7875 - y1_output_root_mean_squared_error: 3.2859 - y2_output_root_mean_squared_error: 4.3527 - val_loss: 18.8848 - val_y1_output_loss: 8.9471 - val_y2_output_loss: 9.3215 - val_y1_output_root_mean_squared_error: 3.0446 - val_y2_output_root_mean_squared_error: 3.1008
# Epoch 6/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.7336 - y1_output_loss: 9.1885 - y2_output_loss: 13.7215 - y1_output_root_mean_squared_error: 3.0204 - y2_output_root_mean_squared_error: 3.6893 - val_loss: 74.0627 - val_y1_output_loss: 19.7340 - val_y2_output_loss: 52.0750 - val_y1_output_root_mean_squared_error: 4.5190 - val_y2_output_root_mean_squared_error: 7.3240
# Epoch 7/500
# 614/614 [==============================] - 0s 138us/sample - loss: 24.6941 - y1_output_loss: 9.1653 - y2_output_loss: 15.9504 - y1_output_root_mean_squared_error: 3.0158 - y2_output_root_mean_squared_error: 3.9496 - val_loss: 24.3787 - val_y1_output_loss: 7.6367 - val_y2_output_loss: 15.9758 - val_y1_output_root_mean_squared_error: 2.8111 - val_y2_output_root_mean_squared_error: 4.0591
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.5120 - y1_output_loss: 8.7255 - y2_output_loss: 14.0569 - y1_output_root_mean_squared_error: 2.9488 - y2_output_root_mean_squared_error: 3.7171 - val_loss: 41.8727 - val_y1_output_loss: 13.7180 - val_y2_output_loss: 26.6529 - val_y1_output_root_mean_squared_error: 3.7727 - val_y2_output_root_mean_squared_error: 5.2573
# Epoch 9/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.2858 - y1_output_loss: 8.4549 - y2_output_loss: 15.2170 - y1_output_root_mean_squared_error: 2.9028 - y2_output_root_mean_squared_error: 3.8548 - val_loss: 109.8187 - val_y1_output_loss: 14.8487 - val_y2_output_loss: 91.5791 - val_y1_output_root_mean_squared_error: 3.9231 - val_y2_output_root_mean_squared_error: 9.7174
# Epoch 10/500
# 614/614 [==============================] - 0s 150us/sample - loss: 31.3950 - y1_output_loss: 10.3014 - y2_output_loss: 21.0393 - y1_output_root_mean_squared_error: 3.2122 - y2_output_root_mean_squared_error: 4.5909 - val_loss: 41.7263 - val_y1_output_loss: 11.1105 - val_y2_output_loss: 29.2742 - val_y1_output_root_mean_squared_error: 3.3944 - val_y2_output_root_mean_squared_error: 5.4958
# Epoch 11/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.9190 - y1_output_loss: 8.4546 - y2_output_loss: 13.5674 - y1_output_root_mean_squared_error: 2.8893 - y2_output_root_mean_squared_error: 3.6839 - val_loss: 19.9811 - val_y1_output_loss: 6.9533 - val_y2_output_loss: 12.3563 - val_y1_output_root_mean_squared_error: 2.6829 - val_y2_output_root_mean_squared_error: 3.5754
# Epoch 12/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.2963 - y1_output_loss: 8.5712 - y2_output_loss: 15.6527 - y1_output_root_mean_squared_error: 2.9175 - y2_output_root_mean_squared_error: 3.9729 - val_loss: 15.2935 - val_y1_output_loss: 7.0939 - val_y2_output_loss: 7.7435 - val_y1_output_root_mean_squared_error: 2.7082 - val_y2_output_root_mean_squared_error: 2.8212
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.8078 - y1_output_loss: 7.3780 - y2_output_loss: 12.3929 - y1_output_root_mean_squared_error: 2.7258 - y2_output_root_mean_squared_error: 3.5182 - val_loss: 14.4409 - val_y1_output_loss: 6.2067 - val_y2_output_loss: 7.7299 - val_y1_output_root_mean_squared_error: 2.5355 - val_y2_output_root_mean_squared_error: 2.8306
# Epoch 14/500
# 614/614 [==============================] - 0s 133us/sample - loss: 18.5558 - y1_output_loss: 7.3775 - y2_output_loss: 11.2625 - y1_output_root_mean_squared_error: 2.6959 - y2_output_root_mean_squared_error: 3.3598 - val_loss: 23.1981 - val_y1_output_loss: 10.3314 - val_y2_output_loss: 12.0583 - val_y1_output_root_mean_squared_error: 3.2709 - val_y2_output_root_mean_squared_error: 3.5355
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.4642 - y1_output_loss: 7.4921 - y2_output_loss: 11.8146 - y1_output_root_mean_squared_error: 2.7464 - y2_output_root_mean_squared_error: 3.4527 - val_loss: 14.0456 - val_y1_output_loss: 6.5009 - val_y2_output_loss: 7.0846 - val_y1_output_root_mean_squared_error: 2.5936 - val_y2_output_root_mean_squared_error: 2.7054
# Epoch 16/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.3070 - y1_output_loss: 7.0819 - y2_output_loss: 11.3423 - y1_output_root_mean_squared_error: 2.6635 - y2_output_root_mean_squared_error: 3.3485 - val_loss: 14.0704 - val_y1_output_loss: 6.4840 - val_y2_output_loss: 7.1574 - val_y1_output_root_mean_squared_error: 2.5852 - val_y2_output_root_mean_squared_error: 2.7179
# Epoch 17/500
# 614/614 [==============================] - 0s 144us/sample - loss: 18.4019 - y1_output_loss: 6.9770 - y2_output_loss: 11.4971 - y1_output_root_mean_squared_error: 2.6436 - y2_output_root_mean_squared_error: 3.3784 - val_loss: 12.8083 - val_y1_output_loss: 5.8726 - val_y2_output_loss: 6.5221 - val_y1_output_root_mean_squared_error: 2.4631 - val_y2_output_root_mean_squared_error: 2.5964
# Epoch 18/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.0195 - y1_output_loss: 6.6298 - y2_output_loss: 10.5730 - y1_output_root_mean_squared_error: 2.5506 - y2_output_root_mean_squared_error: 3.2425 - val_loss: 39.1513 - val_y1_output_loss: 13.2376 - val_y2_output_loss: 24.5765 - val_y1_output_root_mean_squared_error: 3.7029 - val_y2_output_root_mean_squared_error: 5.0438
# Epoch 19/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.4454 - y1_output_loss: 6.3117 - y2_output_loss: 11.1816 - y1_output_root_mean_squared_error: 2.5146 - y2_output_root_mean_squared_error: 3.3350 - val_loss: 41.9399 - val_y1_output_loss: 12.7399 - val_y2_output_loss: 27.7632 - val_y1_output_root_mean_squared_error: 3.6342 - val_y2_output_root_mean_squared_error: 5.3602
# Epoch 20/500
# 614/614 [==============================] - 0s 138us/sample - loss: 15.8445 - y1_output_loss: 6.2518 - y2_output_loss: 9.4668 - y1_output_root_mean_squared_error: 2.5091 - y2_output_root_mean_squared_error: 3.0902 - val_loss: 10.3876 - val_y1_output_loss: 4.9280 - val_y2_output_loss: 5.0959 - val_y1_output_root_mean_squared_error: 2.2590 - val_y2_output_root_mean_squared_error: 2.2988
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.0051 - y1_output_loss: 5.6902 - y2_output_loss: 9.2185 - y1_output_root_mean_squared_error: 2.3941 - y2_output_root_mean_squared_error: 3.0452 - val_loss: 12.3963 - val_y1_output_loss: 4.8479 - val_y2_output_loss: 7.1330 - val_y1_output_root_mean_squared_error: 2.2412 - val_y2_output_root_mean_squared_error: 2.7154
# Epoch 22/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.5004 - y1_output_loss: 5.6788 - y2_output_loss: 9.7012 - y1_output_root_mean_squared_error: 2.3903 - y2_output_root_mean_squared_error: 3.1284 - val_loss: 10.8844 - val_y1_output_loss: 5.3402 - val_y2_output_loss: 5.1469 - val_y1_output_root_mean_squared_error: 2.3537 - val_y2_output_root_mean_squared_error: 2.3118
# Epoch 23/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.1618 - y1_output_loss: 5.4152 - y2_output_loss: 9.7066 - y1_output_root_mean_squared_error: 2.3315 - y2_output_root_mean_squared_error: 3.1187 - val_loss: 16.6014 - val_y1_output_loss: 7.1411 - val_y2_output_loss: 8.8688 - val_y1_output_root_mean_squared_error: 2.7210 - val_y2_output_root_mean_squared_error: 3.0327
# Epoch 24/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.8283 - y1_output_loss: 5.7616 - y2_output_loss: 10.9251 - y1_output_root_mean_squared_error: 2.4114 - y2_output_root_mean_squared_error: 3.3187 - val_loss: 14.8670 - val_y1_output_loss: 4.5942 - val_y2_output_loss: 9.7653 - val_y1_output_root_mean_squared_error: 2.1748 - val_y2_output_root_mean_squared_error: 3.1839
# Epoch 25/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.6624 - y1_output_loss: 4.7053 - y2_output_loss: 8.0545 - y1_output_root_mean_squared_error: 2.1635 - y2_output_root_mean_squared_error: 2.8252 - val_loss: 27.6781 - val_y1_output_loss: 6.3288 - val_y2_output_loss: 20.4634 - val_y1_output_root_mean_squared_error: 2.5623 - val_y2_output_root_mean_squared_error: 4.5948
# Epoch 26/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.5997 - y1_output_loss: 5.2517 - y2_output_loss: 10.2350 - y1_output_root_mean_squared_error: 2.2960 - y2_output_root_mean_squared_error: 3.2137 - val_loss: 10.3268 - val_y1_output_loss: 4.3071 - val_y2_output_loss: 5.7047 - val_y1_output_root_mean_squared_error: 2.1057 - val_y2_output_root_mean_squared_error: 2.4276
# Epoch 27/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.7214 - y1_output_loss: 4.3403 - y2_output_loss: 7.5351 - y1_output_root_mean_squared_error: 2.0788 - y2_output_root_mean_squared_error: 2.7203 - val_loss: 21.3307 - val_y1_output_loss: 4.7955 - val_y2_output_loss: 15.8276 - val_y1_output_root_mean_squared_error: 2.2302 - val_y2_output_root_mean_squared_error: 4.0444
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.9669 - y1_output_loss: 4.4325 - y2_output_loss: 8.4409 - y1_output_root_mean_squared_error: 2.1116 - y2_output_root_mean_squared_error: 2.9169 - val_loss: 10.8329 - val_y1_output_loss: 5.4265 - val_y2_output_loss: 5.0423 - val_y1_output_root_mean_squared_error: 2.3685 - val_y2_output_root_mean_squared_error: 2.2854
# Epoch 29/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.6464 - y1_output_loss: 4.7197 - y2_output_loss: 9.0167 - y1_output_root_mean_squared_error: 2.1753 - y2_output_root_mean_squared_error: 2.9857 - val_loss: 32.3167 - val_y1_output_loss: 5.5713 - val_y2_output_loss: 25.6333 - val_y1_output_root_mean_squared_error: 2.4018 - val_y2_output_root_mean_squared_error: 5.1525
# Epoch 30/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.8815 - y1_output_loss: 3.9611 - y2_output_loss: 6.8372 - y1_output_root_mean_squared_error: 1.9959 - y2_output_root_mean_squared_error: 2.6264 - val_loss: 7.5890 - val_y1_output_loss: 3.5540 - val_y2_output_loss: 3.7905 - val_y1_output_root_mean_squared_error: 1.9147 - val_y2_output_root_mean_squared_error: 1.9807
# Epoch 31/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.3937 - y1_output_loss: 4.1009 - y2_output_loss: 7.2144 - y1_output_root_mean_squared_error: 2.0293 - y2_output_root_mean_squared_error: 2.6974 - val_loss: 7.7744 - val_y1_output_loss: 3.3521 - val_y2_output_loss: 4.1588 - val_y1_output_root_mean_squared_error: 1.8616 - val_y2_output_root_mean_squared_error: 2.0758
# Epoch 32/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.9366 - y1_output_loss: 3.7482 - y2_output_loss: 7.3006 - y1_output_root_mean_squared_error: 1.9196 - y2_output_root_mean_squared_error: 2.6929 - val_loss: 19.3765 - val_y1_output_loss: 6.0577 - val_y2_output_loss: 12.6319 - val_y1_output_root_mean_squared_error: 2.5066 - val_y2_output_root_mean_squared_error: 3.6185
# Epoch 33/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.8227 - y1_output_loss: 3.5008 - y2_output_loss: 7.2726 - y1_output_root_mean_squared_error: 1.8734 - y2_output_root_mean_squared_error: 2.7043 - val_loss: 11.5342 - val_y1_output_loss: 4.6162 - val_y2_output_loss: 6.5282 - val_y1_output_root_mean_squared_error: 2.1831 - val_y2_output_root_mean_squared_error: 2.6015
# Epoch 34/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.8652 - y1_output_loss: 3.6605 - y2_output_loss: 7.1647 - y1_output_root_mean_squared_error: 1.9178 - y2_output_root_mean_squared_error: 2.6809 - val_loss: 8.3663 - val_y1_output_loss: 3.2595 - val_y2_output_loss: 4.8200 - val_y1_output_root_mean_squared_error: 1.8348 - val_y2_output_root_mean_squared_error: 2.2360
# Epoch 35/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.1446 - y1_output_loss: 3.3963 - y2_output_loss: 6.7892 - y1_output_root_mean_squared_error: 1.8406 - y2_output_root_mean_squared_error: 2.5994 - val_loss: 13.6722 - val_y1_output_loss: 4.2466 - val_y2_output_loss: 9.0156 - val_y1_output_root_mean_squared_error: 2.0906 - val_y2_output_root_mean_squared_error: 3.0499
# Epoch 36/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.4931 - y1_output_loss: 3.2963 - y2_output_loss: 6.2138 - y1_output_root_mean_squared_error: 1.7950 - y2_output_root_mean_squared_error: 2.5042 - val_loss: 7.4634 - val_y1_output_loss: 2.9769 - val_y2_output_loss: 4.2692 - val_y1_output_root_mean_squared_error: 1.7502 - val_y2_output_root_mean_squared_error: 2.0976
# Epoch 37/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.3642 - y1_output_loss: 2.8558 - y2_output_loss: 5.5064 - y1_output_root_mean_squared_error: 1.6912 - y2_output_root_mean_squared_error: 2.3460 - val_loss: 6.9595 - val_y1_output_loss: 3.0531 - val_y2_output_loss: 3.7844 - val_y1_output_root_mean_squared_error: 1.7619 - val_y2_output_root_mean_squared_error: 1.9635
# Epoch 38/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.4315 - y1_output_loss: 3.1934 - y2_output_loss: 6.1850 - y1_output_root_mean_squared_error: 1.7945 - y2_output_root_mean_squared_error: 2.4923 - val_loss: 9.5085 - val_y1_output_loss: 2.9301 - val_y2_output_loss: 6.2581 - val_y1_output_root_mean_squared_error: 1.7399 - val_y2_output_root_mean_squared_error: 2.5458
# Epoch 39/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.4864 - y1_output_loss: 3.4226 - y2_output_loss: 7.9595 - y1_output_root_mean_squared_error: 1.8586 - y2_output_root_mean_squared_error: 2.8341 - val_loss: 14.9746 - val_y1_output_loss: 5.0081 - val_y2_output_loss: 9.4358 - val_y1_output_root_mean_squared_error: 2.2773 - val_y2_output_root_mean_squared_error: 3.1286
# Epoch 40/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.7697 - y1_output_loss: 2.9068 - y2_output_loss: 5.8455 - y1_output_root_mean_squared_error: 1.7001 - y2_output_root_mean_squared_error: 2.4248 - val_loss: 7.0720 - val_y1_output_loss: 3.1750 - val_y2_output_loss: 3.6792 - val_y1_output_root_mean_squared_error: 1.8078 - val_y2_output_root_mean_squared_error: 1.9504
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9912 - y1_output_loss: 2.8105 - y2_output_loss: 6.3196 - y1_output_root_mean_squared_error: 1.6539 - y2_output_root_mean_squared_error: 2.5012 - val_loss: 31.4653 - val_y1_output_loss: 9.8133 - val_y2_output_loss: 20.5946 - val_y1_output_root_mean_squared_error: 3.1879 - val_y2_output_root_mean_squared_error: 4.6155
# Epoch 42/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.0701 - y1_output_loss: 3.0357 - y2_output_loss: 7.9706 - y1_output_root_mean_squared_error: 1.7450 - y2_output_root_mean_squared_error: 2.8329 - val_loss: 6.8817 - val_y1_output_loss: 2.7206 - val_y2_output_loss: 4.0041 - val_y1_output_root_mean_squared_error: 1.6672 - val_y2_output_root_mean_squared_error: 2.0254
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4039 - y1_output_loss: 2.5444 - y2_output_loss: 5.7815 - y1_output_root_mean_squared_error: 1.6021 - y2_output_root_mean_squared_error: 2.4160 - val_loss: 8.8291 - val_y1_output_loss: 2.5859 - val_y2_output_loss: 5.9384 - val_y1_output_root_mean_squared_error: 1.6344 - val_y2_output_root_mean_squared_error: 2.4815
# Epoch 44/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.5563 - y1_output_loss: 2.4367 - y2_output_loss: 5.0560 - y1_output_root_mean_squared_error: 1.5678 - y2_output_root_mean_squared_error: 2.2579 - val_loss: 4.9062 - val_y1_output_loss: 2.1852 - val_y2_output_loss: 2.5689 - val_y1_output_root_mean_squared_error: 1.4988 - val_y2_output_root_mean_squared_error: 1.6309
# Epoch 45/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0164 - y1_output_loss: 2.2340 - y2_output_loss: 4.7238 - y1_output_root_mean_squared_error: 1.5008 - y2_output_root_mean_squared_error: 2.1827 - val_loss: 4.5087 - val_y1_output_loss: 1.8324 - val_y2_output_loss: 2.5319 - val_y1_output_root_mean_squared_error: 1.3731 - val_y2_output_root_mean_squared_error: 1.6196
# Epoch 46/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.7651 - y1_output_loss: 2.7155 - y2_output_loss: 6.0174 - y1_output_root_mean_squared_error: 1.6441 - y2_output_root_mean_squared_error: 2.4621 - val_loss: 15.6487 - val_y1_output_loss: 5.1980 - val_y2_output_loss: 9.9207 - val_y1_output_root_mean_squared_error: 2.3173 - val_y2_output_root_mean_squared_error: 3.2061
# Epoch 47/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.4473 - y1_output_loss: 2.3442 - y2_output_loss: 5.1442 - y1_output_root_mean_squared_error: 1.5243 - y2_output_root_mean_squared_error: 2.2636 - val_loss: 13.1391 - val_y1_output_loss: 4.1870 - val_y2_output_loss: 8.5793 - val_y1_output_root_mean_squared_error: 2.0756 - val_y2_output_root_mean_squared_error: 2.9717
# Epoch 48/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.7391 - y1_output_loss: 2.3655 - y2_output_loss: 5.3502 - y1_output_root_mean_squared_error: 1.5360 - y2_output_root_mean_squared_error: 2.3194 - val_loss: 6.7801 - val_y1_output_loss: 2.4770 - val_y2_output_loss: 4.0726 - val_y1_output_root_mean_squared_error: 1.5986 - val_y2_output_root_mean_squared_error: 2.0554
# Epoch 49/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.1268 - y1_output_loss: 1.7887 - y2_output_loss: 4.3767 - y1_output_root_mean_squared_error: 1.3420 - y2_output_root_mean_squared_error: 2.0799 - val_loss: 13.1686 - val_y1_output_loss: 2.7896 - val_y2_output_loss: 9.9680 - val_y1_output_root_mean_squared_error: 1.6977 - val_y2_output_root_mean_squared_error: 3.2072
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.3681 - y1_output_loss: 1.9960 - y2_output_loss: 4.3595 - y1_output_root_mean_squared_error: 1.4146 - y2_output_root_mean_squared_error: 2.0897 - val_loss: 7.0556 - val_y1_output_loss: 2.8140 - val_y2_output_loss: 4.0158 - val_y1_output_root_mean_squared_error: 1.7029 - val_y2_output_root_mean_squared_error: 2.0386
# Epoch 51/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.3385 - y1_output_loss: 2.0902 - y2_output_loss: 5.1874 - y1_output_root_mean_squared_error: 1.4506 - y2_output_root_mean_squared_error: 2.2879 - val_loss: 4.5231 - val_y1_output_loss: 1.8151 - val_y2_output_loss: 2.5590 - val_y1_output_root_mean_squared_error: 1.3677 - val_y2_output_root_mean_squared_error: 1.6286
# Epoch 52/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.7650 - y1_output_loss: 1.7658 - y2_output_loss: 3.9708 - y1_output_root_mean_squared_error: 1.3344 - y2_output_root_mean_squared_error: 1.9961 - val_loss: 4.8401 - val_y1_output_loss: 1.7508 - val_y2_output_loss: 2.9340 - val_y1_output_root_mean_squared_error: 1.3416 - val_y2_output_root_mean_squared_error: 1.7436
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.1037 - y1_output_loss: 2.0460 - y2_output_loss: 5.0308 - y1_output_root_mean_squared_error: 1.4298 - y2_output_root_mean_squared_error: 2.2493 - val_loss: 6.2631 - val_y1_output_loss: 2.5151 - val_y2_output_loss: 3.5272 - val_y1_output_root_mean_squared_error: 1.6134 - val_y2_output_root_mean_squared_error: 1.9131
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.0172 - y1_output_loss: 1.9499 - y2_output_loss: 4.1048 - y1_output_root_mean_squared_error: 1.3926 - y2_output_root_mean_squared_error: 2.0194 - val_loss: 6.3164 - val_y1_output_loss: 2.2001 - val_y2_output_loss: 3.9201 - val_y1_output_root_mean_squared_error: 1.5049 - val_y2_output_root_mean_squared_error: 2.0129
# Epoch 55/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.1966 - y1_output_loss: 2.0803 - y2_output_loss: 4.0626 - y1_output_root_mean_squared_error: 1.4490 - y2_output_root_mean_squared_error: 2.0241 - val_loss: 5.0083 - val_y1_output_loss: 2.0639 - val_y2_output_loss: 2.8001 - val_y1_output_root_mean_squared_error: 1.4552 - val_y2_output_root_mean_squared_error: 1.7002
# Epoch 56/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.6267 - y1_output_loss: 1.9505 - y2_output_loss: 4.7349 - y1_output_root_mean_squared_error: 1.3956 - y2_output_root_mean_squared_error: 2.1631 - val_loss: 13.2545 - val_y1_output_loss: 3.8158 - val_y2_output_loss: 8.9631 - val_y1_output_root_mean_squared_error: 1.9885 - val_y2_output_root_mean_squared_error: 3.0496
# Epoch 57/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.9253 - y1_output_loss: 1.7255 - y2_output_loss: 4.1691 - y1_output_root_mean_squared_error: 1.3183 - y2_output_root_mean_squared_error: 2.0463 - val_loss: 4.6872 - val_y1_output_loss: 1.4169 - val_y2_output_loss: 3.1272 - val_y1_output_root_mean_squared_error: 1.2083 - val_y2_output_root_mean_squared_error: 1.7964
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4943 - y1_output_loss: 1.7079 - y2_output_loss: 4.7654 - y1_output_root_mean_squared_error: 1.3028 - y2_output_root_mean_squared_error: 2.1902 - val_loss: 6.1552 - val_y1_output_loss: 2.2423 - val_y2_output_loss: 3.7266 - val_y1_output_root_mean_squared_error: 1.5183 - val_y2_output_root_mean_squared_error: 1.9621
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6095 - y1_output_loss: 1.9362 - y2_output_loss: 4.6346 - y1_output_root_mean_squared_error: 1.3916 - y2_output_root_mean_squared_error: 2.1617 - val_loss: 3.5058 - val_y1_output_loss: 1.2089 - val_y2_output_loss: 2.1885 - val_y1_output_root_mean_squared_error: 1.1154 - val_y2_output_root_mean_squared_error: 1.5039
# Epoch 60/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.4448 - y1_output_loss: 1.5812 - y2_output_loss: 3.8403 - y1_output_root_mean_squared_error: 1.2562 - y2_output_root_mean_squared_error: 1.9664 - val_loss: 8.6246 - val_y1_output_loss: 3.4056 - val_y2_output_loss: 4.9308 - val_y1_output_root_mean_squared_error: 1.8749 - val_y2_output_root_mean_squared_error: 2.2604
# Epoch 61/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.3165 - y1_output_loss: 1.8250 - y2_output_loss: 4.4385 - y1_output_root_mean_squared_error: 1.3562 - y2_output_root_mean_squared_error: 2.1159 - val_loss: 3.8495 - val_y1_output_loss: 1.3927 - val_y2_output_loss: 2.3411 - val_y1_output_root_mean_squared_error: 1.1967 - val_y2_output_root_mean_squared_error: 1.5548
# Epoch 62/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2774 - y1_output_loss: 1.1952 - y2_output_loss: 3.0591 - y1_output_root_mean_squared_error: 1.0967 - y2_output_root_mean_squared_error: 1.7535 - val_loss: 5.1399 - val_y1_output_loss: 1.3816 - val_y2_output_loss: 3.5887 - val_y1_output_root_mean_squared_error: 1.1937 - val_y2_output_root_mean_squared_error: 1.9274
# Epoch 63/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.1536 - y1_output_loss: 1.2964 - y2_output_loss: 3.8976 - y1_output_root_mean_squared_error: 1.1362 - y2_output_root_mean_squared_error: 1.9654 - val_loss: 24.1608 - val_y1_output_loss: 5.9069 - val_y2_output_loss: 17.4893 - val_y1_output_root_mean_squared_error: 2.4721 - val_y2_output_root_mean_squared_error: 4.2485
# Epoch 64/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.6908 - y1_output_loss: 1.9787 - y2_output_loss: 5.6764 - y1_output_root_mean_squared_error: 1.4115 - y2_output_root_mean_squared_error: 2.3871 - val_loss: 3.6609 - val_y1_output_loss: 1.5551 - val_y2_output_loss: 1.9922 - val_y1_output_root_mean_squared_error: 1.2636 - val_y2_output_root_mean_squared_error: 1.4367
# Epoch 65/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.4412 - y1_output_loss: 1.1478 - y2_output_loss: 3.2604 - y1_output_root_mean_squared_error: 1.0758 - y2_output_root_mean_squared_error: 1.8121 - val_loss: 4.4367 - val_y1_output_loss: 1.7917 - val_y2_output_loss: 2.5255 - val_y1_output_root_mean_squared_error: 1.3552 - val_y2_output_root_mean_squared_error: 1.6125
# Epoch 66/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.0829 - y1_output_loss: 1.0500 - y2_output_loss: 3.0414 - y1_output_root_mean_squared_error: 1.0268 - y2_output_root_mean_squared_error: 1.7403 - val_loss: 6.5306 - val_y1_output_loss: 1.5701 - val_y2_output_loss: 4.7444 - val_y1_output_root_mean_squared_error: 1.2713 - val_y2_output_root_mean_squared_error: 2.2168
# Epoch 67/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.6687 - y1_output_loss: 1.2979 - y2_output_loss: 3.5353 - y1_output_root_mean_squared_error: 1.1003 - y2_output_root_mean_squared_error: 1.8596 - val_loss: 22.2739 - val_y1_output_loss: 8.7883 - val_y2_output_loss: 12.6604 - val_y1_output_root_mean_squared_error: 3.0204 - val_y2_output_root_mean_squared_error: 3.6264
# Epoch 68/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.8487 - y1_output_loss: 1.3306 - y2_output_loss: 3.4942 - y1_output_root_mean_squared_error: 1.1589 - y2_output_root_mean_squared_error: 1.8723 - val_loss: 6.3305 - val_y1_output_loss: 1.0194 - val_y2_output_loss: 5.0987 - val_y1_output_root_mean_squared_error: 1.0241 - val_y2_output_root_mean_squared_error: 2.2982
# Epoch 69/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6183 - y1_output_loss: 0.9428 - y2_output_loss: 2.6788 - y1_output_root_mean_squared_error: 0.9681 - y2_output_root_mean_squared_error: 1.6374 - val_loss: 3.3295 - val_y1_output_loss: 1.0325 - val_y2_output_loss: 2.1832 - val_y1_output_root_mean_squared_error: 1.0314 - val_y2_output_root_mean_squared_error: 1.5052
# Epoch 70/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.9836 - y1_output_loss: 1.0596 - y2_output_loss: 2.9066 - y1_output_root_mean_squared_error: 1.0282 - y2_output_root_mean_squared_error: 1.7107 - val_loss: 3.3253 - val_y1_output_loss: 0.8491 - val_y2_output_loss: 2.3804 - val_y1_output_root_mean_squared_error: 0.9319 - val_y2_output_root_mean_squared_error: 1.5674
# Epoch 71/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.8415 - y1_output_loss: 0.9024 - y2_output_loss: 2.9693 - y1_output_root_mean_squared_error: 0.9538 - y2_output_root_mean_squared_error: 1.7123 - val_loss: 2.6159 - val_y1_output_loss: 0.8695 - val_y2_output_loss: 1.6610 - val_y1_output_root_mean_squared_error: 0.9449 - val_y2_output_root_mean_squared_error: 1.3126
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.4198 - y1_output_loss: 1.1202 - y2_output_loss: 3.3315 - y1_output_root_mean_squared_error: 1.0552 - y2_output_root_mean_squared_error: 1.8184 - val_loss: 9.2951 - val_y1_output_loss: 3.8157 - val_y2_output_loss: 5.1659 - val_y1_output_root_mean_squared_error: 1.9872 - val_y2_output_root_mean_squared_error: 2.3122
# Epoch 73/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.9677 - y1_output_loss: 1.5104 - y2_output_loss: 3.4889 - y1_output_root_mean_squared_error: 1.2266 - y2_output_root_mean_squared_error: 1.8609 - val_loss: 16.6209 - val_y1_output_loss: 4.6253 - val_y2_output_loss: 11.3963 - val_y1_output_root_mean_squared_error: 2.1867 - val_y2_output_root_mean_squared_error: 3.4408
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.9002 - y1_output_loss: 0.9856 - y2_output_loss: 2.8850 - y1_output_root_mean_squared_error: 0.9971 - y2_output_root_mean_squared_error: 1.7047 - val_loss: 10.8036 - val_y1_output_loss: 3.8532 - val_y2_output_loss: 6.6208 - val_y1_output_root_mean_squared_error: 1.9875 - val_y2_output_root_mean_squared_error: 2.6179
# Epoch 75/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7408 - y1_output_loss: 1.0838 - y2_output_loss: 3.6449 - y1_output_root_mean_squared_error: 1.0301 - y2_output_root_mean_squared_error: 1.9183 - val_loss: 2.8384 - val_y1_output_loss: 1.1084 - val_y2_output_loss: 1.6447 - val_y1_output_root_mean_squared_error: 1.0675 - val_y2_output_root_mean_squared_error: 1.3034
# Epoch 76/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5362 - y1_output_loss: 0.8570 - y2_output_loss: 2.6510 - y1_output_root_mean_squared_error: 0.9282 - y2_output_root_mean_squared_error: 1.6354 - val_loss: 2.4674 - val_y1_output_loss: 0.7943 - val_y2_output_loss: 1.5956 - val_y1_output_root_mean_squared_error: 0.9006 - val_y2_output_root_mean_squared_error: 1.2870
# Epoch 77/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8064 - y1_output_loss: 0.7300 - y2_output_loss: 2.0731 - y1_output_root_mean_squared_error: 0.8510 - y2_output_root_mean_squared_error: 1.4430 - val_loss: 3.3226 - val_y1_output_loss: 1.0947 - val_y2_output_loss: 2.1271 - val_y1_output_root_mean_squared_error: 1.0598 - val_y2_output_root_mean_squared_error: 1.4831
# Epoch 78/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.2976 - y1_output_loss: 0.7245 - y2_output_loss: 2.6246 - y1_output_root_mean_squared_error: 0.8371 - y2_output_root_mean_squared_error: 1.6115 - val_loss: 25.8746 - val_y1_output_loss: 9.8066 - val_y2_output_loss: 15.1328 - val_y1_output_root_mean_squared_error: 3.1885 - val_y2_output_root_mean_squared_error: 3.9633
# Epoch 79/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6274 - y1_output_loss: 1.0824 - y2_output_loss: 3.5325 - y1_output_root_mean_squared_error: 1.0422 - y2_output_root_mean_squared_error: 1.8818 - val_loss: 3.9118 - val_y1_output_loss: 0.9004 - val_y2_output_loss: 2.8923 - val_y1_output_root_mean_squared_error: 0.9605 - val_y2_output_root_mean_squared_error: 1.7289
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0647 - y1_output_loss: 0.7383 - y2_output_loss: 2.3019 - y1_output_root_mean_squared_error: 0.8624 - y2_output_root_mean_squared_error: 1.5235 - val_loss: 2.1530 - val_y1_output_loss: 0.6213 - val_y2_output_loss: 1.4795 - val_y1_output_root_mean_squared_error: 0.7926 - val_y2_output_root_mean_squared_error: 1.2348
# Epoch 81/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9968 - y1_output_loss: 0.7238 - y2_output_loss: 2.2734 - y1_output_root_mean_squared_error: 0.8535 - y2_output_root_mean_squared_error: 1.5061 - val_loss: 3.8766 - val_y1_output_loss: 0.6992 - val_y2_output_loss: 3.0481 - val_y1_output_root_mean_squared_error: 0.8469 - val_y2_output_root_mean_squared_error: 1.7775
# Epoch 82/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7754 - y1_output_loss: 0.6250 - y2_output_loss: 2.1424 - y1_output_root_mean_squared_error: 0.7925 - y2_output_root_mean_squared_error: 1.4654 - val_loss: 3.5507 - val_y1_output_loss: 1.0407 - val_y2_output_loss: 2.4326 - val_y1_output_root_mean_squared_error: 1.0277 - val_y2_output_root_mean_squared_error: 1.5794
# Epoch 83/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4752 - y1_output_loss: 0.8186 - y2_output_loss: 2.6724 - y1_output_root_mean_squared_error: 0.9061 - y2_output_root_mean_squared_error: 1.6291 - val_loss: 2.5667 - val_y1_output_loss: 0.6138 - val_y2_output_loss: 1.8902 - val_y1_output_root_mean_squared_error: 0.7868 - val_y2_output_root_mean_squared_error: 1.3956
# Epoch 84/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7220 - y1_output_loss: 1.0800 - y2_output_loss: 2.6310 - y1_output_root_mean_squared_error: 1.0430 - y2_output_root_mean_squared_error: 1.6230 - val_loss: 3.3132 - val_y1_output_loss: 0.7922 - val_y2_output_loss: 2.4190 - val_y1_output_root_mean_squared_error: 0.9025 - val_y2_output_root_mean_squared_error: 1.5807
# Epoch 85/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2987 - y1_output_loss: 0.6813 - y2_output_loss: 2.6143 - y1_output_root_mean_squared_error: 0.8273 - y2_output_root_mean_squared_error: 1.6169 - val_loss: 4.3147 - val_y1_output_loss: 0.7828 - val_y2_output_loss: 3.4111 - val_y1_output_root_mean_squared_error: 0.8931 - val_y2_output_root_mean_squared_error: 1.8754
# Epoch 86/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.1986 - y1_output_loss: 0.8160 - y2_output_loss: 2.4357 - y1_output_root_mean_squared_error: 0.9048 - y2_output_root_mean_squared_error: 1.5427 - val_loss: 2.7852 - val_y1_output_loss: 0.9891 - val_y2_output_loss: 1.7051 - val_y1_output_root_mean_squared_error: 1.0070 - val_y2_output_root_mean_squared_error: 1.3308
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9618 - y1_output_loss: 0.6359 - y2_output_loss: 2.3538 - y1_output_root_mean_squared_error: 0.7966 - y2_output_root_mean_squared_error: 1.5255 - val_loss: 5.1715 - val_y1_output_loss: 0.9410 - val_y2_output_loss: 4.0690 - val_y1_output_root_mean_squared_error: 0.9853 - val_y2_output_root_mean_squared_error: 2.0496
# Epoch 88/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8663 - y1_output_loss: 0.8891 - y2_output_loss: 2.9665 - y1_output_root_mean_squared_error: 0.9427 - y2_output_root_mean_squared_error: 1.7256 - val_loss: 2.3990 - val_y1_output_loss: 0.9285 - val_y2_output_loss: 1.3975 - val_y1_output_root_mean_squared_error: 0.9790 - val_y2_output_root_mean_squared_error: 1.2002
# Epoch 89/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1270 - y1_output_loss: 0.7508 - y2_output_loss: 2.3907 - y1_output_root_mean_squared_error: 0.8676 - y2_output_root_mean_squared_error: 1.5409 - val_loss: 15.2549 - val_y1_output_loss: 3.4445 - val_y2_output_loss: 11.3585 - val_y1_output_root_mean_squared_error: 1.8822 - val_y2_output_root_mean_squared_error: 3.4223
# Epoch 90/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6021 - y1_output_loss: 0.9365 - y2_output_loss: 2.6430 - y1_output_root_mean_squared_error: 0.9710 - y2_output_root_mean_squared_error: 1.6307 - val_loss: 2.7036 - val_y1_output_loss: 0.8245 - val_y2_output_loss: 1.8451 - val_y1_output_root_mean_squared_error: 0.9088 - val_y2_output_root_mean_squared_error: 1.3703
# Epoch 91/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6545 - y1_output_loss: 0.8836 - y2_output_loss: 2.7414 - y1_output_root_mean_squared_error: 0.9431 - y2_output_root_mean_squared_error: 1.6628 - val_loss: 4.2574 - val_y1_output_loss: 0.7281 - val_y2_output_loss: 3.4090 - val_y1_output_root_mean_squared_error: 0.8647 - val_y2_output_root_mean_squared_error: 1.8734
# Epoch 92/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6078 - y1_output_loss: 0.6594 - y2_output_loss: 1.9845 - y1_output_root_mean_squared_error: 0.8071 - y2_output_root_mean_squared_error: 1.3987 - val_loss: 2.0003 - val_y1_output_loss: 0.6369 - val_y2_output_loss: 1.2968 - val_y1_output_root_mean_squared_error: 0.8087 - val_y2_output_root_mean_squared_error: 1.1603
# Epoch 93/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.8654 - y1_output_loss: 0.9631 - y2_output_loss: 2.8803 - y1_output_root_mean_squared_error: 0.9842 - y2_output_root_mean_squared_error: 1.7020 - val_loss: 2.6459 - val_y1_output_loss: 0.8255 - val_y2_output_loss: 1.7346 - val_y1_output_root_mean_squared_error: 0.9207 - val_y2_output_root_mean_squared_error: 1.3410
# Epoch 94/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9598 - y1_output_loss: 0.6222 - y2_output_loss: 2.3239 - y1_output_root_mean_squared_error: 0.7903 - y2_output_root_mean_squared_error: 1.5281 - val_loss: 2.6079 - val_y1_output_loss: 1.0113 - val_y2_output_loss: 1.5149 - val_y1_output_root_mean_squared_error: 1.0200 - val_y2_output_root_mean_squared_error: 1.2520
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6733 - y1_output_loss: 0.5946 - y2_output_loss: 2.0725 - y1_output_root_mean_squared_error: 0.7738 - y2_output_root_mean_squared_error: 1.4404 - val_loss: 2.2524 - val_y1_output_loss: 0.5720 - val_y2_output_loss: 1.6111 - val_y1_output_root_mean_squared_error: 0.7612 - val_y2_output_root_mean_squared_error: 1.2935
# Epoch 96/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1706 - y1_output_loss: 0.7729 - y2_output_loss: 2.3765 - y1_output_root_mean_squared_error: 0.8808 - y2_output_root_mean_squared_error: 1.5475 - val_loss: 3.5306 - val_y1_output_loss: 1.4093 - val_y2_output_loss: 1.9977 - val_y1_output_root_mean_squared_error: 1.2065 - val_y2_output_root_mean_squared_error: 1.4405
# Epoch 97/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3517 - y1_output_loss: 0.7749 - y2_output_loss: 2.5771 - y1_output_root_mean_squared_error: 0.8819 - y2_output_root_mean_squared_error: 1.6044 - val_loss: 3.8379 - val_y1_output_loss: 0.6249 - val_y2_output_loss: 3.1112 - val_y1_output_root_mean_squared_error: 0.8018 - val_y2_output_root_mean_squared_error: 1.7875
# Epoch 98/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.6517 - y1_output_loss: 1.2276 - y2_output_loss: 3.3859 - y1_output_root_mean_squared_error: 1.1132 - y2_output_root_mean_squared_error: 1.8473 - val_loss: 2.1040 - val_y1_output_loss: 0.4879 - val_y2_output_loss: 1.5473 - val_y1_output_root_mean_squared_error: 0.7076 - val_y2_output_root_mean_squared_error: 1.2662
# Epoch 99/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7421 - y1_output_loss: 1.0195 - y2_output_loss: 2.7637 - y1_output_root_mean_squared_error: 0.9980 - y2_output_root_mean_squared_error: 1.6571 - val_loss: 10.9522 - val_y1_output_loss: 4.8810 - val_y2_output_loss: 6.0344 - val_y1_output_root_mean_squared_error: 2.2122 - val_y2_output_root_mean_squared_error: 2.4614
# Epoch 100/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.4959 - y1_output_loss: 1.4280 - y2_output_loss: 4.3992 - y1_output_root_mean_squared_error: 1.1723 - y2_output_root_mean_squared_error: 2.0302 - val_loss: 82.8842 - val_y1_output_loss: 26.8968 - val_y2_output_loss: 52.9288 - val_y1_output_root_mean_squared_error: 5.2860 - val_y2_output_root_mean_squared_error: 7.4123
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.1609 - y1_output_loss: 1.1211 - y2_output_loss: 3.0109 - y1_output_root_mean_squared_error: 1.0623 - y2_output_root_mean_squared_error: 1.7413 - val_loss: 2.4792 - val_y1_output_loss: 0.8670 - val_y2_output_loss: 1.5367 - val_y1_output_root_mean_squared_error: 0.9456 - val_y2_output_root_mean_squared_error: 1.2590
# Epoch 102/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3436 - y1_output_loss: 0.5543 - y2_output_loss: 1.7741 - y1_output_root_mean_squared_error: 0.7479 - y2_output_root_mean_squared_error: 1.3358 - val_loss: 2.5033 - val_y1_output_loss: 0.8179 - val_y2_output_loss: 1.5976 - val_y1_output_root_mean_squared_error: 0.9196 - val_y2_output_root_mean_squared_error: 1.2875
# Epoch 103/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.3446 - y1_output_loss: 0.5515 - y2_output_loss: 1.7804 - y1_output_root_mean_squared_error: 0.7456 - y2_output_root_mean_squared_error: 1.3374 - val_loss: 2.4403 - val_y1_output_loss: 0.6016 - val_y2_output_loss: 1.7584 - val_y1_output_root_mean_squared_error: 0.7853 - val_y2_output_root_mean_squared_error: 1.3504
# Epoch 104/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.0762 - y1_output_loss: 0.4393 - y2_output_loss: 1.6315 - y1_output_root_mean_squared_error: 0.6609 - y2_output_root_mean_squared_error: 1.2804 - val_loss: 3.7004 - val_y1_output_loss: 1.3575 - val_y2_output_loss: 2.2088 - val_y1_output_root_mean_squared_error: 1.1868 - val_y2_output_root_mean_squared_error: 1.5139
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6410 - y1_output_loss: 0.6046 - y2_output_loss: 2.0161 - y1_output_root_mean_squared_error: 0.7796 - y2_output_root_mean_squared_error: 1.4259 - val_loss: 2.0916 - val_y1_output_loss: 0.6491 - val_y2_output_loss: 1.3752 - val_y1_output_root_mean_squared_error: 0.8175 - val_y2_output_root_mean_squared_error: 1.1931
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2621 - y1_output_loss: 0.4778 - y2_output_loss: 1.7720 - y1_output_root_mean_squared_error: 0.6937 - y2_output_root_mean_squared_error: 1.3345 - val_loss: 2.0429 - val_y1_output_loss: 0.4630 - val_y2_output_loss: 1.5116 - val_y1_output_root_mean_squared_error: 0.6903 - val_y2_output_root_mean_squared_error: 1.2516
# Epoch 107/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2531 - y1_output_loss: 0.4804 - y2_output_loss: 1.7682 - y1_output_root_mean_squared_error: 0.6918 - y2_output_root_mean_squared_error: 1.3321 - val_loss: 2.6508 - val_y1_output_loss: 1.1132 - val_y2_output_loss: 1.4493 - val_y1_output_root_mean_squared_error: 1.0723 - val_y2_output_root_mean_squared_error: 1.2252
# Epoch 108/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9757 - y1_output_loss: 0.9813 - y2_output_loss: 2.9731 - y1_output_root_mean_squared_error: 0.9942 - y2_output_root_mean_squared_error: 1.7284 - val_loss: 3.3848 - val_y1_output_loss: 1.0432 - val_y2_output_loss: 2.2285 - val_y1_output_root_mean_squared_error: 1.0379 - val_y2_output_root_mean_squared_error: 1.5191
# Epoch 109/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5103 - y1_output_loss: 0.5951 - y2_output_loss: 1.8941 - y1_output_root_mean_squared_error: 0.7748 - y2_output_root_mean_squared_error: 1.3820 - val_loss: 4.1337 - val_y1_output_loss: 1.4925 - val_y2_output_loss: 2.5056 - val_y1_output_root_mean_squared_error: 1.2406 - val_y2_output_root_mean_squared_error: 1.6108
# Epoch 110/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6573 - y1_output_loss: 0.6293 - y2_output_loss: 2.0270 - y1_output_root_mean_squared_error: 0.7954 - y2_output_root_mean_squared_error: 1.4229 - val_loss: 2.4685 - val_y1_output_loss: 0.5231 - val_y2_output_loss: 1.8638 - val_y1_output_root_mean_squared_error: 0.7346 - val_y2_output_root_mean_squared_error: 1.3888
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.8813 - y1_output_loss: 0.4463 - y2_output_loss: 1.4242 - y1_output_root_mean_squared_error: 0.6687 - y2_output_root_mean_squared_error: 1.1976 - val_loss: 1.6129 - val_y1_output_loss: 0.4339 - val_y2_output_loss: 1.1246 - val_y1_output_root_mean_squared_error: 0.6685 - val_y2_output_root_mean_squared_error: 1.0798
# Epoch 112/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2591 - y1_output_loss: 0.4805 - y2_output_loss: 1.9094 - y1_output_root_mean_squared_error: 0.6815 - y2_output_root_mean_squared_error: 1.3397 - val_loss: 13.5102 - val_y1_output_loss: 4.1076 - val_y2_output_loss: 8.9740 - val_y1_output_root_mean_squared_error: 2.0580 - val_y2_output_root_mean_squared_error: 3.0454
# Epoch 113/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5378 - y1_output_loss: 0.6254 - y2_output_loss: 1.9840 - y1_output_root_mean_squared_error: 0.7899 - y2_output_root_mean_squared_error: 1.3834 - val_loss: 12.2916 - val_y1_output_loss: 1.2875 - val_y2_output_loss: 10.5827 - val_y1_output_root_mean_squared_error: 1.1511 - val_y2_output_root_mean_squared_error: 3.3116
# Epoch 114/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3815 - y1_output_loss: 0.8707 - y2_output_loss: 2.4843 - y1_output_root_mean_squared_error: 0.9357 - y2_output_root_mean_squared_error: 1.5830 - val_loss: 1.9624 - val_y1_output_loss: 0.4389 - val_y2_output_loss: 1.4555 - val_y1_output_root_mean_squared_error: 0.6715 - val_y2_output_root_mean_squared_error: 1.2294
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.9205 - y1_output_loss: 0.4153 - y2_output_loss: 1.5019 - y1_output_root_mean_squared_error: 0.6463 - y2_output_root_mean_squared_error: 1.2259 - val_loss: 1.6351 - val_y1_output_loss: 0.4805 - val_y2_output_loss: 1.0980 - val_y1_output_root_mean_squared_error: 0.7038 - val_y2_output_root_mean_squared_error: 1.0676
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.0873 - y1_output_loss: 0.4278 - y2_output_loss: 1.6405 - y1_output_root_mean_squared_error: 0.6569 - y2_output_root_mean_squared_error: 1.2868 - val_loss: 1.9980 - val_y1_output_loss: 0.6331 - val_y2_output_loss: 1.2987 - val_y1_output_root_mean_squared_error: 0.8079 - val_y2_output_root_mean_squared_error: 1.1599
# Epoch 117/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3593 - y1_output_loss: 0.4961 - y2_output_loss: 1.8506 - y1_output_root_mean_squared_error: 0.7049 - y2_output_root_mean_squared_error: 1.3647 - val_loss: 2.1081 - val_y1_output_loss: 0.6833 - val_y2_output_loss: 1.3520 - val_y1_output_root_mean_squared_error: 0.8390 - val_y2_output_root_mean_squared_error: 1.1850
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6152 - y1_output_loss: 0.5982 - y2_output_loss: 2.0115 - y1_output_root_mean_squared_error: 0.7740 - y2_output_root_mean_squared_error: 1.4199 - val_loss: 3.2502 - val_y1_output_loss: 0.8788 - val_y2_output_loss: 2.2654 - val_y1_output_root_mean_squared_error: 0.9496 - val_y2_output_root_mean_squared_error: 1.5325
# Epoch 119/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.0822 - y1_output_loss: 0.4768 - y2_output_loss: 1.5998 - y1_output_root_mean_squared_error: 0.6865 - y2_output_root_mean_squared_error: 1.2692 - val_loss: 3.1990 - val_y1_output_loss: 1.0227 - val_y2_output_loss: 2.0674 - val_y1_output_root_mean_squared_error: 1.0282 - val_y2_output_root_mean_squared_error: 1.4635
# Epoch 120/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.4006 - y1_output_loss: 0.5060 - y2_output_loss: 1.8836 - y1_output_root_mean_squared_error: 0.7102 - y2_output_root_mean_squared_error: 1.3770 - val_loss: 2.1760 - val_y1_output_loss: 0.5193 - val_y2_output_loss: 1.5861 - val_y1_output_root_mean_squared_error: 0.7291 - val_y2_output_root_mean_squared_error: 1.2823
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3270 - y1_output_loss: 0.1044 - y2_output_loss: 0.2218 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4723 - val_loss: 0.6136 - val_y1_output_loss: 0.2035 - val_y2_output_loss: 0.3960 - val_y1_output_root_mean_squared_error: 0.4534 - val_y2_output_root_mean_squared_error: 0.6388
# Epoch 462/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.6106 - y1_output_loss: 0.1919 - y2_output_loss: 0.4165 - y1_output_root_mean_squared_error: 0.4400 - y2_output_root_mean_squared_error: 0.6457 - val_loss: 0.7013 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.4908 - val_y1_output_root_mean_squared_error: 0.4625 - val_y2_output_root_mean_squared_error: 0.6981
# Epoch 463/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3429 - y1_output_loss: 0.1144 - y2_output_loss: 0.2270 - y1_output_root_mean_squared_error: 0.3391 - y2_output_root_mean_squared_error: 0.4774 - val_loss: 0.5423 - val_y1_output_loss: 0.1619 - val_y2_output_loss: 0.3669 - val_y1_output_root_mean_squared_error: 0.4071 - val_y2_output_root_mean_squared_error: 0.6136
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3426 - y1_output_loss: 0.1072 - y2_output_loss: 0.2362 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4844 - val_loss: 0.8195 - val_y1_output_loss: 0.1927 - val_y2_output_loss: 0.6151 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.7909
# Epoch 465/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4825 - y1_output_loss: 0.1417 - y2_output_loss: 0.3389 - y1_output_root_mean_squared_error: 0.3758 - y2_output_root_mean_squared_error: 0.5841 - val_loss: 0.7614 - val_y1_output_loss: 0.2433 - val_y2_output_loss: 0.5018 - val_y1_output_root_mean_squared_error: 0.4984 - val_y2_output_root_mean_squared_error: 0.7162
# Epoch 466/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2799 - y1_output_loss: 0.0885 - y2_output_loss: 0.1900 - y1_output_root_mean_squared_error: 0.2984 - y2_output_root_mean_squared_error: 0.4369 - val_loss: 0.5647 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.3543 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 0.6045
# Epoch 467/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4045 - y1_output_loss: 0.1136 - y2_output_loss: 0.2900 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.5390 - val_loss: 0.8191 - val_y1_output_loss: 0.2560 - val_y2_output_loss: 0.5512 - val_y1_output_root_mean_squared_error: 0.5144 - val_y2_output_root_mean_squared_error: 0.7447
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3804 - y1_output_loss: 0.1192 - y2_output_loss: 0.2665 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5114 - val_loss: 1.2154 - val_y1_output_loss: 0.3038 - val_y2_output_loss: 0.8756 - val_y1_output_root_mean_squared_error: 0.5610 - val_y2_output_root_mean_squared_error: 0.9490
# Epoch 469/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3437 - y1_output_loss: 0.1033 - y2_output_loss: 0.2390 - y1_output_root_mean_squared_error: 0.3205 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 0.8694 - val_y1_output_loss: 0.2456 - val_y2_output_loss: 0.5936 - val_y1_output_root_mean_squared_error: 0.5041 - val_y2_output_root_mean_squared_error: 0.7844
# Epoch 470/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3111 - y1_output_loss: 0.0992 - y2_output_loss: 0.2097 - y1_output_root_mean_squared_error: 0.3157 - y2_output_root_mean_squared_error: 0.4598 - val_loss: 0.5686 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.3475 - val_y1_output_root_mean_squared_error: 0.4586 - val_y2_output_root_mean_squared_error: 0.5986
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2918 - y1_output_loss: 0.1092 - y2_output_loss: 0.1810 - y1_output_root_mean_squared_error: 0.3309 - y2_output_root_mean_squared_error: 0.4270 - val_loss: 0.6419 - val_y1_output_loss: 0.2053 - val_y2_output_loss: 0.4218 - val_y1_output_root_mean_squared_error: 0.4563 - val_y2_output_root_mean_squared_error: 0.6585
# Epoch 472/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3018 - y1_output_loss: 0.1083 - y2_output_loss: 0.1920 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4401 - val_loss: 0.7062 - val_y1_output_loss: 0.2825 - val_y2_output_loss: 0.4035 - val_y1_output_root_mean_squared_error: 0.5390 - val_y2_output_root_mean_squared_error: 0.6447
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3215 - y1_output_loss: 0.1139 - y2_output_loss: 0.2094 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.4551 - val_loss: 0.7526 - val_y1_output_loss: 0.2124 - val_y2_output_loss: 0.5205 - val_y1_output_root_mean_squared_error: 0.4656 - val_y2_output_root_mean_squared_error: 0.7320
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3523 - y1_output_loss: 0.1104 - y2_output_loss: 0.2417 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.4925 - val_loss: 0.7012 - val_y1_output_loss: 0.2347 - val_y2_output_loss: 0.4452 - val_y1_output_root_mean_squared_error: 0.4914 - val_y2_output_root_mean_squared_error: 0.6780
# Epoch 475/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3781 - y1_output_loss: 0.1177 - y2_output_loss: 0.2583 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5097 - val_loss: 0.6136 - val_y1_output_loss: 0.1910 - val_y2_output_loss: 0.4060 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.6456
# Epoch 476/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2822 - y1_output_loss: 0.0991 - y2_output_loss: 0.1817 - y1_output_root_mean_squared_error: 0.3161 - y2_output_root_mean_squared_error: 0.4270 - val_loss: 0.5603 - val_y1_output_loss: 0.1856 - val_y2_output_loss: 0.3676 - val_y1_output_root_mean_squared_error: 0.4357 - val_y2_output_root_mean_squared_error: 0.6086
# Epoch 477/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3471 - y1_output_loss: 0.1131 - y2_output_loss: 0.2377 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4841 - val_loss: 0.7689 - val_y1_output_loss: 0.2081 - val_y2_output_loss: 0.5374 - val_y1_output_root_mean_squared_error: 0.4619 - val_y2_output_root_mean_squared_error: 0.7453
# Epoch 478/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2677 - y1_output_loss: 0.0941 - y2_output_loss: 0.1726 - y1_output_root_mean_squared_error: 0.3068 - y2_output_root_mean_squared_error: 0.4165 - val_loss: 0.6836 - val_y1_output_loss: 0.2123 - val_y2_output_loss: 0.4605 - val_y1_output_root_mean_squared_error: 0.4634 - val_y2_output_root_mean_squared_error: 0.6848
# Epoch 479/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4171 - y1_output_loss: 0.1224 - y2_output_loss: 0.2962 - y1_output_root_mean_squared_error: 0.3486 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 0.6329 - val_y1_output_loss: 0.2017 - val_y2_output_loss: 0.4374 - val_y1_output_root_mean_squared_error: 0.4554 - val_y2_output_root_mean_squared_error: 0.6524
# Epoch 480/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3255 - y1_output_loss: 0.1004 - y2_output_loss: 0.2260 - y1_output_root_mean_squared_error: 0.3179 - y2_output_root_mean_squared_error: 0.4738 - val_loss: 1.0360 - val_y1_output_loss: 0.3884 - val_y2_output_loss: 0.6135 - val_y1_output_root_mean_squared_error: 0.6322 - val_y2_output_root_mean_squared_error: 0.7977
# Epoch 481/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3336 - y1_output_loss: 0.1157 - y2_output_loss: 0.2165 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.4660 - val_loss: 0.7087 - val_y1_output_loss: 0.2174 - val_y2_output_loss: 0.4740 - val_y1_output_root_mean_squared_error: 0.4690 - val_y2_output_root_mean_squared_error: 0.6991
# Epoch 482/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3170 - y1_output_loss: 0.1053 - y2_output_loss: 0.2105 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4605 - val_loss: 0.6704 - val_y1_output_loss: 0.2063 - val_y2_output_loss: 0.4447 - val_y1_output_root_mean_squared_error: 0.4620 - val_y2_output_root_mean_squared_error: 0.6760
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3666 - y1_output_loss: 0.1138 - y2_output_loss: 0.2513 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 0.6042 - val_y1_output_loss: 0.1753 - val_y2_output_loss: 0.4199 - val_y1_output_root_mean_squared_error: 0.4251 - val_y2_output_root_mean_squared_error: 0.6508
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2915 - y1_output_loss: 0.1018 - y2_output_loss: 0.1898 - y1_output_root_mean_squared_error: 0.3174 - y2_output_root_mean_squared_error: 0.4368 - val_loss: 0.6623 - val_y1_output_loss: 0.2380 - val_y2_output_loss: 0.4164 - val_y1_output_root_mean_squared_error: 0.4920 - val_y2_output_root_mean_squared_error: 0.6482
# Epoch 485/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4246 - y1_output_loss: 0.1268 - y2_output_loss: 0.2955 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.5446 - val_loss: 0.7691 - val_y1_output_loss: 0.2597 - val_y2_output_loss: 0.4841 - val_y1_output_root_mean_squared_error: 0.5174 - val_y2_output_root_mean_squared_error: 0.7081
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4257 - y1_output_loss: 0.1296 - y2_output_loss: 0.2933 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5431 - val_loss: 0.6229 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 0.4374 - val_y1_output_root_mean_squared_error: 0.4268 - val_y2_output_root_mean_squared_error: 0.6639
# Epoch 487/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3879 - y1_output_loss: 0.1235 - y2_output_loss: 0.2619 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5137 - val_loss: 0.6386 - val_y1_output_loss: 0.1708 - val_y2_output_loss: 0.4512 - val_y1_output_root_mean_squared_error: 0.4175 - val_y2_output_root_mean_squared_error: 0.6814
# Epoch 488/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2613 - y1_output_loss: 0.0995 - y2_output_loss: 0.1600 - y1_output_root_mean_squared_error: 0.3163 - y2_output_root_mean_squared_error: 0.4016 - val_loss: 0.7646 - val_y1_output_loss: 0.2098 - val_y2_output_loss: 0.5314 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_root_mean_squared_error: 0.7398
# Epoch 489/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2703 - y1_output_loss: 0.1069 - y2_output_loss: 0.1624 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.4041 - val_loss: 0.7477 - val_y1_output_loss: 0.2681 - val_y2_output_loss: 0.4654 - val_y1_output_root_mean_squared_error: 0.5242 - val_y2_output_root_mean_squared_error: 0.6877
# Epoch 490/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2818 - y1_output_loss: 0.0985 - y2_output_loss: 0.1833 - y1_output_root_mean_squared_error: 0.3148 - y2_output_root_mean_squared_error: 0.4274 - val_loss: 0.6669 - val_y1_output_loss: 0.2346 - val_y2_output_loss: 0.4145 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.6534
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.2811 - y1_output_loss: 0.1061 - y2_output_loss: 0.1750 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.4173 - val_loss: 0.5655 - val_y1_output_loss: 0.1864 - val_y2_output_loss: 0.3618 - val_y1_output_root_mean_squared_error: 0.4375 - val_y2_output_root_mean_squared_error: 0.6116
# Epoch 492/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3331 - y1_output_loss: 0.1117 - y2_output_loss: 0.2209 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.4698 - val_loss: 0.7543 - val_y1_output_loss: 0.2289 - val_y2_output_loss: 0.5108 - val_y1_output_root_mean_squared_error: 0.4826 - val_y2_output_root_mean_squared_error: 0.7221
# Epoch 493/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2814 - y1_output_loss: 0.0983 - y2_output_loss: 0.1821 - y1_output_root_mean_squared_error: 0.3146 - y2_output_root_mean_squared_error: 0.4271 - val_loss: 0.4991 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 0.3296 - val_y1_output_root_mean_squared_error: 0.4070 - val_y2_output_root_mean_squared_error: 0.5774
# Epoch 494/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2968 - y1_output_loss: 0.0981 - y2_output_loss: 0.1965 - y1_output_root_mean_squared_error: 0.3144 - y2_output_root_mean_squared_error: 0.4449 - val_loss: 0.5608 - val_y1_output_loss: 0.1741 - val_y2_output_loss: 0.3748 - val_y1_output_root_mean_squared_error: 0.4200 - val_y2_output_root_mean_squared_error: 0.6200
# Epoch 495/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2872 - y1_output_loss: 0.1074 - y2_output_loss: 0.1776 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4231 - val_loss: 0.6116 - val_y1_output_loss: 0.1728 - val_y2_output_loss: 0.4235 - val_y1_output_root_mean_squared_error: 0.4196 - val_y2_output_root_mean_squared_error: 0.6600
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3672 - y1_output_loss: 0.1091 - y2_output_loss: 0.2568 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.5080 - val_loss: 0.8406 - val_y1_output_loss: 0.2889 - val_y2_output_loss: 0.5404 - val_y1_output_root_mean_squared_error: 0.5436 - val_y2_output_root_mean_squared_error: 0.7383
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2586 - y1_output_loss: 0.1023 - y2_output_loss: 0.1548 - y1_output_root_mean_squared_error: 0.3210 - y2_output_root_mean_squared_error: 0.3945 - val_loss: 0.4907 - val_y1_output_loss: 0.1692 - val_y2_output_loss: 0.3112 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 0.5632
# Epoch 498/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3830 - y1_output_loss: 0.1257 - y2_output_loss: 0.2553 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.5569 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 0.3447 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 0.5938
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2623 - y1_output_loss: 0.0953 - y2_output_loss: 0.1678 - y1_output_root_mean_squared_error: 0.3094 - y2_output_root_mean_squared_error: 0.4082 - val_loss: 0.6856 - val_y1_output_loss: 0.2363 - val_y2_output_loss: 0.4313 - val_y1_output_root_mean_squared_error: 0.4918 - val_y2_output_root_mean_squared_error: 0.6661
# Epoch 500/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2477 - y1_output_loss: 0.0965 - y2_output_loss: 0.1505 - y1_output_root_mean_squared_error: 0.3112 - y2_output_root_mean_squared_error: 0.3884 - val_loss: 0.5027 - val_y1_output_loss: 0.1795 - val_y2_output_loss: 0.3083 - val_y1_output_root_mean_squared_error: 0.4299 - val_y2_output_root_mean_squared_error: 0.5638

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 33us/sample - loss: 0.5027 - y1_output_loss: 0.1831 - y2_output_loss: 0.3114 - y1_output_root_mean_squared_error: 0.4299 - y2_output_root_mean_squared_error: 0.5638
# Loss = 0.5027161960477953, Y1_loss = 0.18306097388267517, Y1_mse = 0.4299030005931854, Y2_loss = 0.31140953302383423, Y2_mse = 0.5638258457183838

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
#print(Y_pred)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
